# %% [markdown]
# [![image](https://jupyterlite.rtfd.io/en/latest/_static/badge.svg)](https://demo.leafmap.org/lab/index.html?path=maplibre/layer_control.ipynb)
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/leafmap/blob/master/docs/maplibre/layer_control.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/opengeos/leafmap/HEAD)
#
# **Control layer visibility using the built-in layer control**
#
# Uncomment the following line to install [leafmap](https://leafmap.org) if needed.

# %%
# %pip install "leafmap[maplibre]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting leafmap[maplibre]
#   Downloading leafmap-0.48.3-py2.py3-none-any.whl (567 kB)
#      |████████████████████████████████| 567 kB 1.9 MB/s eta 0:00:01
# Collecting anywidget
#   Downloading anywidget-0.9.18-py3-none-any.whl (220 kB)
#      |████████████████████████████████| 220 kB 2.5 MB/s eta 0:00:01
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
#      |████████████████████████████████| 139 kB 2.9 MB/s eta 0:00:01
# Collecting folium
#   Downloading folium-0.19.7-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 2.2 MB/s eta 0:00:01
# Collecting ipyvuetify
#   Downloading ipyvuetify-1.11.2-py2.py3-none-any.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 1.6 MB/s eta 0:00:01
# Collecting ipyleaflet
#   Downloading ipyleaflet-0.19.2-py3-none-any.whl (31 kB)
# Collecting python-box
#   Downloading python_box-7.3.2-cp39-cp39-macosx_10_9_universal2.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 1.2 MB/s eta 0:00:01
# Collecting whiteboxgui
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 1.9 MB/s eta 0:00:01
# Collecting plotly
#   Downloading plotly-6.1.2-py3-none-any.whl (16.3 MB)
#      |████████████████████████████████| 16.3 MB 2.3 MB/s eta 0:00:01
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#      |████████████████████████████████| 323 kB 1.3 MB/s eta 0:00:01
# Collecting ipyfilechooser
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Collecting scooby
#   Downloading scooby-0.10.1-py3-none-any.whl (18 kB)
# Collecting numpy
#   Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 2.9 MB/s eta 0:00:01
# Collecting duckdb
#   Downloading duckdb-1.3.0-cp39-cp39-macosx_12_0_arm64.whl (15.5 MB)
#      |████████████████████████████████| 15.5 MB 1.8 MB/s eta 0:00:01
# Collecting pandas
#   Downloading pandas-2.3.0-cp39-cp39-macosx_11_0_arm64.whl (10.8 MB)
#      |████████████████████████████████| 10.8 MB 3.8 MB/s eta 0:00:01    |██████████████                  | 4.7 MB 3.2 MB/s eta 0:00:02
# Collecting xyzservices
#   Downloading xyzservices-2025.4.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 2.5 MB/s eta 0:00:01
# Collecting bqplot
#   Downloading bqplot-0.12.45-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 3.1 MB/s eta 0:00:01
# Collecting maplibre
#   Downloading maplibre-0.3.4-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 2.3 MB/s eta 0:00:01
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 2.3 MB/s eta 0:00:01
# Collecting pystac-client
#   Downloading pystac_client-0.8.3-py3-none-any.whl (33 kB)
# Collecting ipyevents
#   Downloading ipyevents-2.0.2-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 2.8 MB/s ta 0:00:01
# Collecting geojson
#   Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Collecting localtileserver
#   Downloading localtileserver-0.10.6-py3-none-any.whl (17.1 MB)
#      |████████████████████████████████| 17.1 MB 4.5 MB/s eta 0:00:01
# Collecting h3
#   Downloading h3-4.2.2-cp39-cp39-macosx_11_0_arm64.whl (835 kB)
#      |████████████████████████████████| 835 kB 1.2 MB/s eta 0:00:01
# Collecting mapclassify
#   Downloading mapclassify-2.8.1-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 3.4 MB/s eta 0:00:011
# Collecting rioxarray
#   Downloading rioxarray-0.15.0-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.2 MB/s eta 0:00:01
# Collecting xarray
#   Downloading xarray-2024.7.0-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 2.9 MB/s eta 0:00:01
# Collecting pmtiles
#   Downloading pmtiles-3.4.1.tar.gz (13 kB)
# Collecting fiona
#   Downloading fiona-1.10.1-cp39-cp39-macosx_11_0_arm64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 3.9 MB/s eta 0:00:01
# Collecting pydantic>=2.5.3
#   Downloading pydantic-2.11.5-py3-none-any.whl (444 kB)
#      |████████████████████████████████| 444 kB 2.2 MB/s eta 0:00:01
# Collecting jinja2>=3.1.6
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 2.0 MB/s eta 0:00:01
# Collecting branca
#   Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Collecting eval-type-backport
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-3.0.2-cp39-cp39-macosx_11_0_arm64.whl (12 kB)
# Collecting pydantic-core==2.33.2
#   Downloading pydantic_core-2.33.2-cp39-cp39-macosx_11_0_arm64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 2.6 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from pydantic>=2.5.3->maplibre->leafmap[maplibre]) (4.12.2)
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting psygnal>=0.8.1
#   Downloading psygnal-0.13.0-cp39-cp39-macosx_11_0_arm64.whl (473 kB)
#      |████████████████████████████████| 473 kB 2.8 MB/s eta 0:00:01
# Collecting widgetsnbextension~=4.0.14
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 3.8 MB/s eta 0:00:01
# Requirement already satisfied: ipython>=6.1.0 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from ipywidgets->leafmap[maplibre]) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from ipywidgets->leafmap[maplibre]) (5.14.3)
# Collecting jupyterlab_widgets~=3.0.15
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
#      |████████████████████████████████| 216 kB 3.1 MB/s eta 0:00:01
# Requirement already satisfied: comm>=0.1.3 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from ipywidgets->leafmap[maplibre]) (0.2.2)
# Requirement already satisfied: jedi>=0.16 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (0.19.2)
# Requirement already satisfied: stack-data in /Users/hong/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (4.9.0)
# Requirement already satisfied: decorator in /Users/hong/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (2.18.0)
# Requirement already satisfied: matplotlib-inline in /Users/hong/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (0.1.7)
# Requirement already satisfied: exceptiongroup in /Users/hong/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (1.2.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (3.0.48)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/hong/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (0.2.13)
# Collecting traittypes>=0.0.6
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      |████████████████████████████████| 347 kB 3.3 MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 3.1 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from pandas->leafmap[maplibre]) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.8.2->pandas->leafmap[maplibre]) (1.17.0)
# Collecting certifi
#   Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
#      |████████████████████████████████| 159 kB 3.2 MB/s eta 0:00:01
# Collecting click~=8.0
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 2.9 MB/s eta 0:00:01
# Requirement already satisfied: importlib-metadata in /Users/hong/Library/Python/3.9/lib/python/site-packages (from fiona->leafmap[maplibre]) (8.5.0)
# Collecting attrs>=19.2.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 3.7 MB/s eta 0:00:011
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting requests
#   Downloading requests-2.32.4-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.7 MB/s eta 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 3.5 MB/s eta 0:00:01
# Collecting filelock
#   Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
#      |████████████████████████████████| 187 kB 3.1 MB/s eta 0:00:01
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Collecting shapely>=2.0.0
#   Downloading shapely-2.0.7-cp39-cp39-macosx_11_0_arm64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 2.9 MB/s eta 0:00:01
# Collecting pyproj>=3.3.0
#   Downloading pyproj-3.6.1-cp39-cp39-macosx_11_0_arm64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 2.9 MB/s eta 0:00:01
# Collecting pyogrio>=0.7.2
#   Downloading pyogrio-0.11.0-cp39-cp39-macosx_12_0_arm64.whl (19.5 MB)
#      |████████████████████████████████| 19.5 MB 4.0 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/hong/Library/Python/3.9/lib/python/site-packages (from geopandas->leafmap[maplibre]) (24.2)
# Requirement already satisfied: zipp>=3.20 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from importlib-metadata->fiona->leafmap[maplibre]) (3.21.0)
# Collecting jupyter-leaflet<0.20,>=0.19
#   Downloading jupyter_leaflet-0.19.2-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 2.7 MB/s eta 0:00:01
# Collecting ipyvue<2,>=1.7
#   Downloading ipyvue-1.11.2-py2.py3-none-any.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 2.9 MB/s eta 0:00:01
# Collecting rio-tiler
#   Downloading rio_tiler-7.8.0-py3-none-any.whl (268 kB)
#      |████████████████████████████████| 268 kB 1.6 MB/s eta 0:00:01
# Collecting server-thread
#   Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Collecting Flask-Caching
#   Downloading Flask_Caching-2.3.1-py3-none-any.whl (28 kB)
# Collecting flask<4,>=2.0.0
#   Downloading flask-3.1.1-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 1.5 MB/s eta 0:00:01
# Collecting flask-cors
#   Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Collecting rio-cogeo
#   Downloading rio_cogeo-5.4.1-py3-none-any.whl (20 kB)
# Collecting flask-restx>=1.3.0
#   Downloading flask_restx-1.3.0-py2.py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 1.6 MB/s eta 0:00:01
# Collecting werkzeug
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      |████████████████████████████████| 224 kB 3.1 MB/s eta 0:00:01
# Collecting blinker>=1.9.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting itsdangerous>=2.2.0
#   Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting jsonschema
#   Downloading jsonschema-4.24.0-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 3.1 MB/s eta 0:00:01
# Collecting aniso8601>=0.82
#   Downloading aniso8601-10.0.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 4.2 MB/s eta 0:00:01
# Collecting importlib-resources
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting cachelib>=0.9.0
#   Downloading cachelib-0.13.0-py3-none-any.whl (20 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.25.1-cp39-cp39-macosx_11_0_arm64.whl (359 kB)
#      |████████████████████████████████| 359 kB 3.1 MB/s eta 0:00:01
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.4.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting scikit-learn>=1.0
#   Downloading scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl (11.1 MB)
#      |████████████████████████████████| 11.1 MB 4.6 MB/s eta 0:00:01    |███████                         | 2.4 MB 2.6 MB/s eta 0:00:04
# Collecting networkx>=2.7
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 4.5 MB/s eta 0:00:01
# Collecting scipy>=1.8
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#      |████████████████████████████████| 30.3 MB 2.5 MB/s eta 0:00:01
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#      |████████████████████████████████| 307 kB 2.1 MB/s eta 0:00:01
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting pillow>=8
#   Downloading pillow-11.2.1-cp39-cp39-macosx_11_0_arm64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 2.7 MB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
#      |████████████████████████████████| 249 kB 4.6 MB/s eta 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.0 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 2.5 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.58.2-cp39-cp39-macosx_10_9_universal2.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 1.7 MB/s eta 0:00:01
# Collecting narwhals>=1.15.1
#   Downloading narwhals-1.42.1-py3-none-any.whl (359 kB)
#      |████████████████████████████████| 359 kB 1.5 MB/s eta 0:00:01
# Collecting pystac[validation]>=1.10.0
#   Downloading pystac-1.10.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 1.7 MB/s eta 0:00:01
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 1.3 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.2-cp39-cp39-macosx_10_9_universal2.whl (201 kB)
#      |████████████████████████████████| 201 kB 1.7 MB/s eta 0:00:01
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting morecantile<7.0,>=5.0
#   Downloading morecantile-6.2.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 2.4 MB/s eta 0:00:01
# Collecting rasterio>=1.3.3
#   Downloading rasterio-1.4.3-cp39-cp39-macosx_14_0_arm64.whl (18.8 MB)
#      |████████████████████████████████| 18.8 MB 3.1 MB/s eta 0:00:01
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Collecting cachetools
#   Downloading cachetools-6.0.0-py3-none-any.whl (10 kB)
# Collecting httpx
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 3.6 MB/s eta 0:00:01
# Collecting color-operations
#   Downloading color_operations-0.2.0-cp39-cp39-macosx_11_0_arm64.whl (49 kB)
#      |████████████████████████████████| 49 kB 4.4 MB/s eta 0:00:01
# Collecting numexpr
#   Downloading numexpr-2.10.2-cp39-cp39-macosx_11_0_arm64.whl (134 kB)
#      |████████████████████████████████| 134 kB 2.5 MB/s eta 0:00:01
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 2.9 MB/s eta 0:00:01
# Collecting anyio
#   Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 4.3 MB/s ta 0:00:01
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.34.3-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 3.0 MB/s eta 0:00:01
# Requirement already satisfied: pure-eval in /Users/hong/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/hong/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->leafmap[maplibre]) (2.1.0)
# Collecting whitebox
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 3.1 MB/s eta 0:00:01
# Collecting ipytree
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 3.6 MB/s eta 0:00:01
# Building wheels for collected packages: pmtiles
#   Building wheel for pmtiles (setup.py) ... done
#   Created wheel for pmtiles: filename=pmtiles-3.4.1-py3-none-any.whl size=15838 sha256=3cfea4fc02154d2035c67e2af84f98a8a359a810d306cd2cf6b0bd939e306c92
#   Stored in directory: /Users/hong/Library/Caches/pip/wheels/a7/18/e7/8af6b175d69af3c4fd7137fac11fd5f58ec66092c6e45522d7
# Successfully built pmtiles
# Installing collected packages: rpds-py, attrs, referencing, widgetsnbextension, urllib3, typing-inspection, sniffio, pydantic-core, MarkupSafe, jupyterlab-widgets, jsonschema-specifications, idna, h11, click, charset-normalizer, certifi, annotated-types, werkzeug, tzdata, soupsieve, requests, pytz, pystac, PySocks, pyproj, pyparsing, pydantic, numpy, jsonschema, jinja2, itsdangerous, ipywidgets, httpcore, cligj, click-plugins, blinker, anyio, affine, xyzservices, whitebox, uvicorn, traittypes, tqdm, threadpoolctl, shapely, scooby, scipy, rasterio, pyogrio, psygnal, pillow, pandas, numexpr, narwhals, morecantile, kiwisolver, jupyter-leaflet, joblib, ipyvue, ipytree, ipyfilechooser, importlib-resources, httpx, fonttools, flask, filelock, eval-type-backport, cycler, contourpy, color-operations, cachetools, cachelib, branca, beautifulsoup4, aniso8601, xarray, whiteboxgui, server-thread, scikit-learn, rio-tiler, rio-cogeo, python-box, pystac-client, plotly, networkx, matplotlib, maplibre, ipyvuetify, ipyleaflet, ipyevents, geopandas, geojson, gdown, folium, flask-restx, flask-cors, Flask-Caching, duckdb, bqplot, anywidget, rioxarray, pmtiles, mapclassify, localtileserver, leafmap, h3, fiona
# Successfully installed Flask-Caching-2.3.1 MarkupSafe-3.0.2 PySocks-1.7.1 affine-2.4.0 aniso8601-10.0.1 annotated-types-0.7.0 anyio-4.9.0 anywidget-0.9.18 attrs-25.3.0 beautifulsoup4-4.13.4 blinker-1.9.0 bqplot-0.12.45 branca-0.8.1 cachelib-0.13.0 cachetools-6.0.0 certifi-2025.4.26 charset-normalizer-3.4.2 click-8.1.8 click-plugins-1.1.1 cligj-0.7.2 color-operations-0.2.0 contourpy-1.3.0 cycler-0.12.1 duckdb-1.3.0 eval-type-backport-0.2.2 filelock-3.18.0 fiona-1.10.1 flask-3.1.1 flask-cors-6.0.1 flask-restx-1.3.0 folium-0.19.7 fonttools-4.58.2 gdown-5.2.0 geojson-3.2.0 geopandas-1.0.1 h11-0.16.0 h3-4.2.2 httpcore-1.0.9 httpx-0.28.1 idna-3.10 importlib-resources-6.5.2 ipyevents-2.0.2 ipyfilechooser-0.6.0 ipyleaflet-0.19.2 ipytree-0.2.2 ipyvue-1.11.2 ipyvuetify-1.11.2 ipywidgets-8.1.7 itsdangerous-2.2.0 jinja2-3.1.6 joblib-1.5.1 jsonschema-4.24.0 jsonschema-specifications-2025.4.1 jupyter-leaflet-0.19.2 jupyterlab-widgets-3.0.15 kiwisolver-1.4.7 leafmap-0.48.3 localtileserver-0.10.6 mapclassify-2.8.1 maplibre-0.3.4 matplotlib-3.9.4 morecantile-6.2.0 narwhals-1.42.1 networkx-3.2.1 numexpr-2.10.2 numpy-2.0.2 pandas-2.3.0 pillow-11.2.1 plotly-6.1.2 pmtiles-3.4.1 psygnal-0.13.0 pydantic-2.11.5 pydantic-core-2.33.2 pyogrio-0.11.0 pyparsing-3.2.3 pyproj-3.6.1 pystac-1.10.1 pystac-client-0.8.3 python-box-7.3.2 pytz-2025.2 rasterio-1.4.3 referencing-0.36.2 requests-2.32.4 rio-cogeo-5.4.1 rio-tiler-7.8.0 rioxarray-0.15.0 rpds-py-0.25.1 scikit-learn-1.6.1 scipy-1.13.1 scooby-0.10.1 server-thread-0.3.0 shapely-2.0.7 sniffio-1.3.1 soupsieve-2.7 threadpoolctl-3.6.0 tqdm-4.67.1 traittypes-0.2.1 typing-inspection-0.4.1 tzdata-2025.2 urllib3-2.4.0 uvicorn-0.34.3 werkzeug-3.1.3 whitebox-2.3.6 whiteboxgui-2.3.0 widgetsnbextension-4.0.14 xarray-2024.7.0 xyzservices-2025.4.0
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import leafmap.maplibregl as leafmap
# Out:
# /Users/hong/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# To run this notebook, you will need an [API key](https://docs.maptiler.com/cloud/api/authentication-key/) from [MapTiler](https://www.maptiler.com/cloud/). Once you have the API key, you can uncomment the following code block and replace `YOUR_API_KEY` with your actual API key. Then, run the code block code to set the API key as an environment variable.

# %%
import os
os.environ["MAPTILER_KEY"] = "pHWSs971g6lDlkcqBBVO	"

# %%
m = leafmap.Map(
    center=[-122.19861, 46.21168], zoom=13, pitch=60, bearing=150, style="3d-terrain"
)
m.add_layer_control(bg_layers=True, position="top-left")
m

# %% [markdown]
# ![](https://i.imgur.com/Il0NRId.gif)

# %%
m = leafmap.Map(
    center=[-123.13, 49.254], zoom=11, style="dark-matter", pitch=45, bearing=0
)
url = "https://raw.githubusercontent.com/visgl/deck.gl-data/master/examples/geojson/vancouver-blocks.json"
paint_line = {
    "line-color": "white",
    "line-width": 2,
}
paint_fill = {
    "fill-extrusion-color": {
        "property": "valuePerSqm",
        "stops": [
            [0, "grey"],
            [1000, "yellow"],
            [5000, "orange"],
            [10000, "darkred"],
            [50000, "lightblue"],
        ],
    },
    "fill-extrusion-height": ["*", 10, ["sqrt", ["get", "valuePerSqm"]]],
    "fill-extrusion-opacity": 0.9,
}
m.add_geojson(url, layer_type="line", paint=paint_line, name="blocks-line")
m.add_geojson(url, layer_type="fill-extrusion", paint=paint_fill, name="blocks-fill")
m.add_layer_control(layer_ids=["blocks-line", "blocks-fill"])
m

# %%
m.layer_interact()

# %%
1

# %% [markdown]
# ![](https://i.imgur.com/FXUwvXf.gif)

# %%
m = leafmap.Map(center=[4.4562, 51.9066], zoom=14)
m.add_basemap("Esri.WorldImagery")
url = "https://storage.googleapis.com/ahp-research/overture/pmtiles/overture.pmtiles"

style = {
    "version": 8,
    "sources": {
        "example_source": {
            "type": "vector",
            "url": "pmtiles://" + url,
            "attribution": "PMTiles",
        }
    },
    "layers": [
        {
            "id": "buildings",
            "source": "example_source",
            "source-layer": "buildings",
            "type": "fill",
            "paint": {"fill-color": "#FFFFB3", "fill-opacity": 0.5},
        },
        {
            "id": "places",
            "source": "example_source",
            "source-layer": "places",
            "type": "fill",
            "paint": {"fill-color": "#BEBADA", "fill-opacity": 0.5},
        },
        {
            "id": "roads",
            "source": "example_source",
            "source-layer": "roads",
            "type": "line",
            "paint": {"line-color": "#FB8072"},
        },
    ],
}

m.add_pmtiles(
    url,
    style=style,
    visible=True,
    opacity=1.0,
    tooltip=True,
)
m.set_zoom(14)
m.add_layer_control()
m

# %%
m.layer_interact()

# %% [markdown]
# ![](https://i.imgur.com/BfkjBEJ.gif)
