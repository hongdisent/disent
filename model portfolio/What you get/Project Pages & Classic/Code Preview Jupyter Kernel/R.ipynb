# %%
library(ggplot2)

ggplot(mtcars, aes(x = wt, y = mpg)) +
  geom_point() +
  geom_smooth(method = "lm", formula = y ~ x, se = TRUE, color = "blue") +
  labs(title = "MPG vs Weight with Linear Regression",
       x = "Weight (1000 lbs)",
       y = "Miles per Gallon")
# Out:
# plot without title
